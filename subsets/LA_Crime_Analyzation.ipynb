# %%
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
import time
import scipy as sp
import scipy.stats as stats
import numpy as np
import csv
# %matplotlib inline

counter = 1;

fj=open("codesUnique.csv", "r")
codesReader = csv.reader(fj, delimiter = ',')
codes = []
for row in codesReader:
    codes.append(row)
    
def sepYear(year, data):
    ret = []
    for item in data:
        if(item[1] != 'Date Occured'):
            if(item[1][8:] == str(year)):
                ret.append(item)
    
    return ret

def graphHelper(data, counter, year):
        
    G = nx.Graph()
    G.add_node("AREA " + str(counter))
    for item in data:
        if(item[3] != 'Crime Code'):
            if(item[3] in G.nodes()):
                G["AREA " + str(counter)][item[3]]['weight'] += 1
            else:
                G.add_node(item[3])
                G.add_edge("AREA " + str(counter), item[3], weight=1)
    while(len(G.nodes) > 11):  
        min = 100000000000
        minNode = None
        for node in G.nodes:
            if(node != "AREA " + str(counter)):
                if(G["AREA " + str(counter)] [node] ['weight'] < min):
                    min = G["AREA " + str(counter)] [node] ['weight']
                    minNode = node
        G.remove_node(minNode)
    
    print("AREA " + str(counter) + '_'+ str(year) + ";Crime Code" + ";Frequency" + ";Description")
    for n in G.nodes:
        if(n != "AREA " + str(counter)):
            for i in codes:
                if i[1] == n:
                    desc = i[2]
                    print("AREA " + str(counter) + ";" + str(n) + ";" + str(G["AREA " + str(counter)][n]['weight']) + ";" + desc)
         
    print('\n')
    
    plt.figure(1, figsize = (5,5))
    nx.draw(G, with_labels=True, font_weight='bold')
    plt.savefig('labels_A' + str(counter) + '_' + year + '.png')
    plt.clf()
    
#     with open('tables_A' + str(counter) + '_' + year + '.csv', 'w') as csvfile:
#         fieldnames = ["AREA " + str(counter) + '_'+ str(year), "Crime Code", "Frequency", "Description"]
#         writer = csv.DictWriter(csvfile, lineterminator='\n', fieldnames=fieldnames)
#         writer.writeheader()
#         for n in G.nodes:
#             if(n != "AREA " + str(counter)):
#                 for i in codes:
#                     if i[1] == n:
#                         desc = i[2]
#                         writer.writerow({"AREA " + str(counter) + '_'+ str(year): "AREA " + str(counter), "Crime Code":str(n), "Frequency": str(G["AREA " + str(counter)][n]['weight']), "Description": desc})
        

def makeGraph(fi, counter):
    reader = csv.reader(fi, delimiter = ',')
    data = []
    data10 = []
    data11 = []
    data12 = []
    data13 = []
    data14 = []
    data15 = []
    data16 = []
    data17 = []

    for row in reader:
        data.append(row)
        
    data10 = sepYear(10, data)
    data11 = sepYear(11, data)
    data12 = sepYear(12, data)
    data13 = sepYear(13, data)
    data14 = sepYear(14, data)
    data15 = sepYear(15, data)
    data16 = sepYear(16, data)
    data17 = sepYear(17, data)
    
    
    graphHelper(data10, counter, '2010')
    graphHelper(data11, counter, '2011')
    graphHelper(data12, counter, '2012')
    graphHelper(data13, counter, '2013')
    graphHelper(data14, counter, '2014')
    graphHelper(data15, counter, '2015')
    graphHelper(data16, counter, '2016')
    graphHelper(data17, counter, '2017')
    
        #    print(desc)
    
def kendalTau(l1, l2):
    tau, p_value = stats.kendalltau(l1, l2)
    return tau

# %%
fi=open("a_1.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_2.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_3.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_4.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_5.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_6.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_7.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_8.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_9.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_10.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_11.csv", "r")
makeGraph(fi, counter)
fi.close()
counter+= 1
fi=open("a_12.csv", "r")
makeGraph(fi, counter)
fi.close()

# %%
print("2017 Tau Data")
for y in range(0,12):
    for x in range(0,12):
        fi=open("graph tables/tables_A" + str(y+1) + "_2017.csv")
        fi2=open("graph tables/tables_A" + str(x+1) + "_2017.csv")
        reader = csv.DictReader(fi)
        l1 = []
        l2 = []
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l1.append(value)
        reader = csv.DictReader(fi2)
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l2.append(value)

        tau = kendalTau(l1,l2)
        fi.close()
        fi2.close()
        print(y+1, x+1, tau)

print("\n2016 Tau Data")
for y in range(0,12):
    for x in range(0,12):
        fi=open("graph tables/tables_A" + str(y+1) + "_2016.csv")
        fi2=open("graph tables/tables_A" + str(x+1) + "_2016.csv")
        reader = csv.DictReader(fi)
        l1 = []
        l2 = []
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l1.append(value)
        reader = csv.DictReader(fi2)
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l2.append(value)

        tau = kendalTau(l1,l2)
        fi.close()
        fi2.close()
        print(y+1, x+1, tau)
        
print("\n2015 Tau Data")
for y in range(0,12):
    for x in range(0,12):
        fi=open("graph tables/tables_A" + str(y+1) + "_2015.csv")
        fi2=open("graph tables/tables_A" + str(x+1) + "_2015.csv")
        reader = csv.DictReader(fi)
        l1 = []
        l2 = []
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l1.append(value)
        reader = csv.DictReader(fi2)
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l2.append(value)

        tau = kendalTau(l1,l2)
        fi.close()
        fi2.close()
        print(y+1, x+1, tau)
        
print("\n2014 Tau Data")
for y in range(0,12):
    for x in range(0,12):
        fi=open("graph tables/tables_A" + str(y+1) + "_2014.csv")
        fi2=open("graph tables/tables_A" + str(x+1) + "_2014.csv")
        reader = csv.DictReader(fi)
        l1 = []
        l2 = []
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l1.append(value)
        reader = csv.DictReader(fi2)
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l2.append(value)

        tau = kendalTau(l1,l2)
        fi.close()
        fi2.close()
        print(y+1, x+1, tau)
        
print("\n2013 Tau Data")
for y in range(0,12):
    for x in range(0,12):
        fi=open("graph tables/tables_A" + str(y+1) + "_2013.csv")
        fi2=open("graph tables/tables_A" + str(x+1) + "_2013.csv")
        reader = csv.DictReader(fi)
        l1 = []
        l2 = []
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l1.append(value)
        reader = csv.DictReader(fi2)
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l2.append(value)

        tau = kendalTau(l1,l2)
        fi.close()
        fi2.close()
        print(y+1, x+1, tau)
        
print("\n2012 Tau Data")
for y in range(0,12):
    for x in range(0,12):
        fi=open("graph tables/tables_A" + str(y+1) + "_2012.csv")
        fi2=open("graph tables/tables_A" + str(x+1) + "_2012.csv")
        reader = csv.DictReader(fi)
        l1 = []
        l2 = []
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l1.append(value)
        reader = csv.DictReader(fi2)
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l2.append(value)

        tau = kendalTau(l1,l2)
        fi.close()
        fi2.close()
        print(y+1, x+1, tau)
        
print("\n2011 Tau Data")
for y in range(0,12):
    for x in range(0,12):
        fi=open("graph tables/tables_A" + str(y+1) + "_2011.csv")
        fi2=open("graph tables/tables_A" + str(x+1) + "_2011.csv")
        reader = csv.DictReader(fi)
        l1 = []
        l2 = []
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l1.append(value)
        reader = csv.DictReader(fi2)
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l2.append(value)

        tau = kendalTau(l1,l2)
        fi.close()
        fi2.close()
        print(y+1, x+1, tau)
        
print("\n2010 Tau Data")
for y in range(0,12):
    for x in range(0,12):
        fi=open("graph tables/tables_A" + str(y+1) + "_2010.csv")
        fi2=open("graph tables/tables_A" + str(x+1) + "_2010.csv")
        reader = csv.DictReader(fi)
        l1 = []
        l2 = []
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l1.append(value)
        reader = csv.DictReader(fi2)
        for row in reader:
             for header, value in row.items():
                if(header == "Crime Code"):
                    l2.append(value)

        tau = kendalTau(l1,l2)
        fi.close()
        fi2.close()
        print(y+1, x+1, tau)
# Out:
# 2016 Tau Data
# 1 1 0.9999999999999999
# 1 2 -0.022222222222222223
# 1 3 0.022222222222222223
# 1 4 0.06666666666666667
# 1 5 0.15555555555555553
# 1 6 -0.15555555555555553
# 1 7 -0.1111111111111111
# 1 8 -0.19999999999999998
# 1 9 0.24444444444444444
# 1 10 -0.022222222222222223
# 1 11 0.24444444444444444
# 1 12 0.4222222222222222
# 2 1 -0.022222222222222223
# 2 2 0.9999999999999999
# 2 3 0.3333333333333333
# 2 4 -0.6
# 2 5 0.1111111111111111
# 2 6 0.15555555555555553
# 2 7 0.022222222222222223
# 2 8 0.28888888888888886
# 2 9 0.28888888888888886
# 2 10 0.1111111111111111
# 2 11 0.022222222222222223
# 2 12 0.1111111111111111
# 3 1 0.022222222222222223
# 3 2 0.3333333333333333
# 3 3 0.9999999999999999
# 3 4 -0.28888888888888886
# 3 5 0.06666666666666667
# 3 6 -0.06666666666666667
# 3 7 -0.37777777777777777
# 3 8 -0.19999999999999998
# 3 9 0.06666666666666667
# 3 10 -0.37777777777777777
# 3 11 -0.022222222222222223
# 3 12 -0.1111111111111111
# 4 1 0.06666666666666667
# 4 2 -0.6
# ...
